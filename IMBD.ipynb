# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadovDovud/Data_Science_Projects/blob/main/IMBD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/AsadovDovud/Data_Science_Projects.git"
# Out:
# Cloning into 'Data_Science_Projects'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 14 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (14/14), 176.41 KiB | 945.00 KiB/s, done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data_Science_Projects/IMDB movies/imdb_top_1000.csv", index_col='Series_Title')
df.head()
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                          Released_Year Certificate  Runtime  \
# Series_Title
# The Shawshank Redemption          1994           A  142 min
# The Godfather                     1972           A  175 min
# The Dark Knight                   2008          UA  152 min
# The Godfather: Part II            1974           A  202 min
# 12 Angry Men                      1957           U   96 min
#
#                                          Genre  IMDB_Rating  \
# Series_Title
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, The Shawshank Redemption to The 39 Steps
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     843 non-null    float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 125.0+ KB

# %%
df.drop(columns=['Poster_Link','Certificate','Overview','Director','Star1','Star2','Star3','Star4'], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                          Released_Year  Runtime                         Genre  \
# Series_Title
# The Shawshank Redemption          1994      142                         Drama
# The Godfather                     1972      175                  Crime, Drama
# The Dark Knight                   2008      152          Action, Crime, Drama
# The Godfather: Part II            1974      202                  Crime, Drama
# 12 Angry Men                      1957       96                  Crime, Drama
# ...                                ...      ...                           ...
# Giù la testa                      1971      157           Drama, War, Western
# Kelly's Heroes                    1970      144        Adventure, Comedy, War
# The Jungle Book                   1967       78  Animation, Adventure, Family
# A Hard Day's Night                1964       87        Comedy, Music, Musical
# From Here to Eternity             1953      118           Drama, Romance, War
#
# ...

# %%
# df['Runtime']=df['Runtime'].map(lambda x: x.replace('min', ''))
# df["Runtime"] = df["Runtime"].astype(int)
df["Released_Year"].values
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1994', '1993',
#        '2010', '1999', '2001', '1994', '1966', '2002', '1999', '1990',
#        '1980', '1975', '2019', '2014', '2002', '2001', '1998', '1999',
#        '1997', '1995', '1991', '1977', '1954', '2019', '2014', '2011',
#        '2006', '2006', '2002', '2000', '1998', '1995', '1994', '1994',
#        '1991', '1988', '1985', '1968', '1960', '1942', '1936', '1931',
#        '2018', '2016', '2018', '2019', '2018', '2017', '2012', '2012',
#        '2009', '2008', '2006', '2003', '2000', '1997', '1981', '1980',
#        '1979', '1979', '1964', '1954', '2019', '2012', '2011', '2010',
#        '2009', '2004', '2001', '2000', '2000', '1999', '1997', '1997',
#        '1995', '1995', '1992', '1987', '1986', '1984', '1983', '1983',
#        '1981', '1976', '1973', '1971', '1968', '1965', '1962', '1960',
#        '1959', '1958', '1952', '1944', '1941', '1927', '2018', '2017',
# ...

# %%
df['Gross']=df['Gross'].map(lambda x: x.replace(',', ''))

# %%
#df['Rating'] = df.IMDB_Rating*df.Meta_score/10
df
# Out:
#                          Released_Year  Runtime                         Genre  \
# Series_Title
# The Shawshank Redemption          1994      142                         Drama
# The Godfather                     1972      175                  Crime, Drama
# The Dark Knight                   2008      152          Action, Crime, Drama
# The Godfather: Part II            1974      202                  Crime, Drama
# 12 Angry Men                      1957       96                  Crime, Drama
# ...                                ...      ...                           ...
# Giù la testa                      1971      157           Drama, War, Western
# Kelly's Heroes                    1970      144        Adventure, Comedy, War
# The Jungle Book                   1967       78  Animation, Adventure, Family
# A Hard Day's Night                1964       87        Comedy, Music, Musical
# From Here to Eternity             1953      118           Drama, Romance, War
#
# ...

# %%
#df.drop(columns=['IMDB_Rating','Meta_score'], inplace=True)
df["Gross"] = df["Gross"].astype(int)

# %%
plt.figure(figsize=(20,6))

plt.scatter(df.Gross, df.Rating)
plt.xticks(rotation=90)
plt.show()

# %%
df.Gross.values
# Out:
# array([ 28341469, 134966411, 534858444,  57300000,   4360000, 377845905,
#        107928762,  96898818, 292576195,  37030102, 315544750, 330252182,
#          6100000, 342551365, 171479930,  46836394, 290475067, 112000000,
#         53367844, 188020017,   7563397,  10055859, 216540909, 136801374,
#         57598247, 100125643, 130742922, 322740140,    269061, 335451311,
#         13092000,  13182281,  53089891, 132384315,  32572577, 187705427,
#          6719864,  23341568,  19501238, 422783777, 204843350,  11990401,
#        210609762,   5321508,  32000000,   1024560,    163245,     19181,
#          1661096,   5017246, 190241310, 858373000, 678815482, 209726015,
#        162805434, 448139099,   6532908, 223808164,  11286112,    707481,
#         25544867,   2375308, 248159971,  44017374,  83471511,  78900000,
#           275902,  36764313, 159227644,    687185,   7098492,   6857096,
#        120540719,  34400301,  33225499,  30328156,   3635482, 130096601,
# ...
